# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import json

# %%
url ='https://www.dcu.ie/dcu-events-list.shtml?field_department_tid=All'

# %%
#Opening connection , grabbing the page
uClient = uReq(url)
page_html = uClient.read()

# %%
uClient.close()

# %%
#Parsing
page_soup = soup(page_html, "html.parser")
print(page_soup)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML+RDFa 1.1//EN">
#
# <html dir="ltr" lang="en" version="HTML+RDFa 1.1" xmlns:article="http://ogp.me/ns/article#" xmlns:book="http://ogp.me/ns/book#" xmlns:content="http://purl.org/rss/1.0/modules/content/" xmlns:dc="http://purl.org/dc/terms/" xmlns:foaf="http://xmlns.com/foaf/0.1/" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/ns/product#" xmlns:profile="http://ogp.me/ns/profile#" xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#" xmlns:sioc="http://rdfs.org/sioc/ns#" xmlns:sioct="http://rdfs.org/sioc/types#" xmlns:skos="http://www.w3.org/2004/02/skos/core#" xmlns:video="http://ogp.me/ns/video#" xmlns:xsd="http://www.w3.org/2001/XMLSchema#">
# <head profile="http://www.w3.org/1999/xhtml/vocab">
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="#4F9FB8" name="theme-color"/>
# <meta content="jzWq7LLMiIEk6CgUvJSihSm3EuzUnpvdoQQc0I5lWmQ" name="google-site-verification"/>
# ...

# %%
# Finding each events
article = page_soup.findAll('div',{"class":"events-list-container"})
print(article)
# Out:
# [<div class="events-list-container">
# <div class="events-list-image-container">
# <a href="/dcu-events/2019/Oct/Inaugural-Lecture-Professor-James-OHiggins-Norman-UNESCO-Chair-Tackling-Bullying"><img alt="Inaugural Lecture by Prof James O'Higgins Norman, UNESCO Chair on Tackling Bullying in Schools and Cyberspace" height="194" src="https://www.dcu.ie/sites/default/files/styles/event-list-image-380x194/public/cregan_library_1.jpg?itok=vfQQOeWt" title="Inaugural Lecture by Prof James O'Higgins Norman, UNESCO Chair on Tackling Bullying in Schools and Cyberspace" typeof="foaf:Image" width="380"/></a>
# <span class="date-display-single" content="2019-10-07T16:30:00+01:00" datatype="xsd:dateTime" property="dc:date">7th October, 2019</span>
# </div>
# <div class="events-list-text-container">
# ...

# %%
data_list = []

for container in article:
    #itemlist = container.findAll('li',class_='sfnewsListItem sflistitem')
#print(itemlist)
    date = container.div.text.strip()
    div_tags = container.findAll('div', class_='events-list-text-container')
    d = div_tags[0].text
    var2 = d.split('\n')
    #print(var2)
    summary = var2[1]
    Date = var2[4]
    Location = var2[7]
    Description = var2[11]

    data = {}
    data["Title"] = title
    data["Date"] = Date
    data["Location"] = Location
    data["Description"] = Description
    #data["readmore"] = read_more
    #data["location"] = location
    data_list.append(data)
 
print(data_list)
# Out:
# [{'Title': '7th October, 2019', 'Date': '07/10/2019 - 16:30 to 18:30', 'Location': "Seamus Heaney Lecture Theatre, DCU St Patrick's Campus", 'Description': "Inaugural Lecture by Professor James O'Higgins Norman, UNESCO Chair on Tackling Bullying in Schools and CyberspaceTackling Bullying from the inside out: Shifting Paradigms in Bullying Research and..."}]

# %%
import pandas as pd
df = pd.DataFrame(data_list)

# %%
df
# Out:
#                           Date  \
# 0  07/10/2019 - 16:30 to 18:30
#
#                                          Description  \
# 0  Inaugural Lecture by Professor James O'Higgins...
#
#                                             Location              Title
# 0  Seamus Heaney Lecture Theatre, DCU St Patrick'...  7th October, 2019

# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import json

# %%
url ='https://www.dbs.ie/news-events'

# %%
#Opening connection , grabbing the page
uClient = uReq(url)
page_html = uClient.read()

# %%
uClient.close()

# %%
#Parsing
page_soup = soup(page_html, "html.parser")
print(page_soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-IE" xmlns="https://www.w3.org/1999/xhtml">
# <head><title>
# 	News and Events at DBS
# </title>
# <link href="/StyleSheet/global.css?id=2.4" rel="stylesheet"/><link href="https://fonts.googleapis.com/css?family=Lato:300,400" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 9]><link rel="stylesheet" href="/StyleSheet/ie9.css" type="text/css" /><![endif]-->
# <!--[if lt IE 9]><link rel="stylesheet" href="/StyleSheet/ie8.css" type="text/css" /><![endif]-->
# <meta content="website" property="og:type"/>
# <!-- removed meta -->
# <!-- Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
# w[l] = w[l] || []; w[l].push({
# 'gtm.start':
# new Date().getTime(), event: 'gtm.js'
# }); var f = d.getElementsByTagName(s)[0],
# j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
# 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# })(window, document, 'script', 'dataLayer', 'GTM-WTGV6Q');
# </script>
# <!-- End Google Tag Manager -->
# <script>var _prum = [['id', '52d911a5abe53da00c000000'],
# ['mark', 'firstbyte', (new Date()).getTime()]];
# (function () {
# var s = document.getElementsByTagName('script')[0]
# , p = document.createElement('script');
# p.async = 'async';
# p.src = '//rum-static.pingdom.net/prum.min.js';
# s.parentNode.insertBefore(p, s);
# })();
# </script>
# <script src="/Javascript/jquery-3.4.1.min.js"></script>
# <!-- Facebook Pixel Code -->
# <script>
#         !function (f, b, e, v, n, t, s) {
#             if (f.fbq) return; n = f.fbq = function () {
#                 n.callMethod ?
#                 n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#             };
#             if (!f._fbq) f._fbq = n; n.push = n; n.loaded = !0; n.version = '2.0';
#             n.queue = []; t = b.createElement(e); t.async = !0;
#             t.src = v; s = b.getElementsByTagName(e)[0];
#             s.parentNode.insertBefore(t, s)
#         }(window, document, 'script',
#             'https://connect.facebook.net/en_US/fbevents.js');
#         fbq('init', '506866573181577');
#         fbq('track', 'PageView');
#     </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=506866573181577&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <!-- End Facebook Pixel Code -->
# <link href="App_Themes/Content/CSS/Override.css" rel="stylesheet" type="text/css"/>
# <meta content="News &amp; Events" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="News &amp; Events" property="og:description"/>
# <meta content="https://www.dbs.ie/news-events" property="og:url"/>
# <meta content="Dublin Business School" property="og:site_name"/>
# <meta content="https://www.dbs.ie/images/default-source/dbs-news/david-bradley-jan-o-39-sullivan.jpg?sfvrsn=c08da3e9_4" property="og:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="News &amp; Events" name="twitter:title"/>
# <meta content="News &amp; Events" name="twitter:description"/>
# <meta content="DBSCollege" name="twitter:site"/>
# <meta content="@DBSCollege" name="twitter:creator"/>
# <meta content="https://www.dbs.ie/images/default-source/dbs-news/david-bradley-jan-o-39-sullivan.jpg?sfvrsn=c08da3e9_4" name="twitter:image"/>
# <link href="https://www.dbs.ie/news-events" rel="canonical"/><link class="Telerik_stylesheet" href="https://d35islomi5rx1v.cloudfront.net/ajax/2017.3.913/SiteMap.css" rel="stylesheet" type="text/css"/><link class="Telerik_stylesheet" href="https://d35islomi5rx1v.cloudfront.net/ajax/2017.3.913/Default/SiteMap.Default.css" rel="stylesheet" type="text/css"/><meta content="Sitefinity 10.2.6626.0 SE" name="Generator"/><link href="https://www.dbs.ie/about-dbs/news-and-events/page/2" rel="next"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><script type="text/javascript">
# 	(function() {var _rdDeviceWidth = (window.innerWidth > 0) ? window.innerWidth : screen.width;var _rdDeviceHeight = (window.innerHeight > 0) ? window.innerHeight : screen.height;var _rdOrientation = (window.width > window.height) ? 'landscape' : 'portrait';})();
# </script><link href="/Telerik.Web.UI.WebResource.axd?d=xXLWwJLoniotGGYycF401aHr8FKzDfXvKl1ZspUoAgb6kqMkAjv5KpYf9GPZFfRvITvyT5xMvm9pXqf4fAbXPpMeOX1002T8uIkmk0EiNZytqobfxrDJME9v2vKOyo3mdDx2C_Xaqj-o9qqsxcSFMg2&amp;t=636577066476378381&amp;compress=0&amp;_TSM_CombinedScripts_=%3b%3bTelerik.Sitefinity.Resources%2c+Version%3d10.2.6626.0%2c+Culture%3dneutral%2c+PublicKeyToken%3db28c218413bdf563%3aen%3a75ec3a6b-4122-4e56-a1f4-58f0be0d90a0%3a7a90d6a" rel="stylesheet" type="text/css"/><link href="/Telerik.Web.UI.WebResource.axd?d=xXLWwJLoniotGGYycF401aHr8FKzDfXvKl1ZspUoAgb6kqMkAjv5KpYf9GPZFfRvITvyT5xMvm9pXqf4fAbXPpMeOX1002T8uIkmk0EiNZytqobfxrDJME9v2vKOyo3mdDx2C_Xaqj-o9qqsxcSFMg2&amp;t=636577066476378381&amp;compress=0&amp;_TSM_CombinedScripts_=%3b%3bTelerik.Sitefinity.Resources%2c+Version%3d10.2.6626.0%2c+Culture%3dneutral%2c+PublicKeyToken%3db28c218413bdf563%3aen%3a75ec3a6b-4122-4e56-a1f4-58f0be0d90a0%3a83fa35c7" rel="stylesheet" type="text/css"/><link href="/Sitefinity/Public/ResponsiveDesign/layout_transformations.css?pageDataId=fc2ad029-53ff-6d7e-be9c-ff000003f2be&amp;pageSiteNode=6D87CD29-53FF-6D7E-BE9C-FF000003F2BE/c9471d86-236d-4db8-af93-fabfb5fa3543/SitefinitySiteMap" rel="stylesheet" type="text/css"/><link href="/StyleSheet/dbs_100.css" media="all" rel="stylesheet" type="text/css"/><link href="StyleSheet/Responsive.min.css" media="all and (min-width:0px) and (max-width:320px)" rel="stylesheet" type="text/css"/><link href="StyleSheet/Responsive.min.css" media="only screen and (min-width: 320px) and (max-width: 480px)" rel="stylesheet" type="text/css"/><link href="StyleSheet/Responsive.min.css" media="all and (min-width:480px) and (max-width:960px)" rel="stylesheet" type="text/css"/><link href="StyleSheet/Responsive_Tablet.min.css" media="only screen and (min-width: 600px) and (max-width : 1024px)" rel="stylesheet" type="text/css"/><link href="StyleSheet/responsive_small.min.css" media="all and (min-width:0px) and (max-width:320px)" rel="stylesheet" type="text/css"/><link href="StyleSheet/responsive_small.min.css" media="all and (min-width:0px) and (max-width:480px)" rel="stylesheet" type="text/css"/><link href="StyleSheet/tiny.css" media="all and (min-width:0px) and (max-width:260px)" rel="stylesheet" type="text/css"/><meta content="News &amp; Events" name="description"/><meta content="News &amp; Events" name="keywords"/></head>
# <body>
# <form action="./news-events" id="form1" method="post">
# <div class="aspNetHidden">
# <input id="ctl08_TSSM" name="ctl08_TSSM" type="hidden" value=""/>
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# </div>
# <script src="https://ajax.microsoft.com/ajax/beta/0910/MicrosoftAjax.js" type="text/javascript"></script>
# <script type="text/javascript">
# //<![CDATA[
# (window.Sys && Sys._Application && Sys.Observer)||document.write('<script type="text/javascript" src="https://ajax.microsoft.com/ajax/beta/0910/MicrosoftAjax.js"><\/script>');//]]>
# </script>
# <script src="https://code.jquery.com/jquery-3.4.1.min.js" type="text/javascript"></script>
# <script src="https://code.jquery.com/jquery-migrate-1.2.1.min.js" type="text/javascript"></script>
# <script src="/ScriptResource.axd?d=5G3VBMky-37fAJ6zE100-xdQxc5GPTiv9fmN225PoYseZAYFGQSGH4ZvJVb9kJaxhIdX_ZBGqZ4UtX3QLbLsgXkjE-WPW6aGoCwFxJYqNQOCnA_qLFONTx5ZGva15KfGCrfcrYTCtCkBfH5ZQVJCzE7HWjvKlrjyldhED4UmHfyYfrwJEKhoB5Ad47umFdQj34EoXQuT2bKFTeYmkENFvQ2&amp;t=388ae382" type="text/javascript"></script>
# <script src="/Frontend-Assembly/Telerik.Sitefinity.Frontend.Search/Mvc/Scripts/SearchBox/Search-box.js" type="text/javascript"></script>
# <script src="https://ajax.microsoft.com/ajax/jQuery.Validate/1.8.1/jQuery.Validate.min.js" type="text/javascript"></script>
# <script src="/ScriptResource.axd?d=_hU6ppBNHtMMVANJuG501vqIPTctCFKezP9hf0-cieeayFeiEZdiuUkC-5MWSl4tBVd9Y5c-Emf48msOWMvwAT70GX2n-8aWvwbNssCAbXcyYL76fGKICsKRv4u_gGrhY03U7xvxKrTZhaI5CjmkxUSIFQzU05f7on9WvnIzwA-ejG2e9R978bIwmyyHgMKz0&amp;t=388ae382" type="text/javascript"></script>
# <script src="https://ajax.microsoft.com/ajax/beta/0910/MicrosoftAjaxWebForms.js" type="text/javascript"></script>
# <script type="text/javascript">
# //<![CDATA[
# (window.Sys && Sys.WebForms)||document.write('<script type="text/javascript" src="https://ajax.microsoft.com/ajax/beta/0910/MicrosoftAjaxWebForms.js"><\/script>');//]]>
# </script>
# <script src="/ScriptResource.axd?d=vv1FueaUoLg4njjJjHLoijo1UVWLQfE_o2RtEq79hDxjYWdOQ-hr4VX0acRPXabbY5ojODoiqUl_0D1JH7uHa1lJLymrBHq7ils0Fl4MlrXjZ_8aa4qcyiWfktklw6tSYXjH-W3rQw0ctsESDfDizYKAEEYnUHr0vr936TuBFPGW60AQxljBiF5oxT3D2kXh0&amp;t=14e19e18" type="text/javascript"></script>
# <script src="/ScriptResource.axd?d=lsOMMJAJkZKoOUeIQ0Lka9myx3ATVJlCDAvlP8WARb7PZjy9D-Yc8rCi2bVMySb578QhDlKOUyrqbQxHzhnHjiEGpYwzn6bdz9EQ64a72MMeQIU7NeR_mSDpqCYiQQdpWZPeft2JIT7CA1bsOiEmu_Fge_XIKDnijENUeFEmV-z7eTwZ8Dh0LdlOkMyOwe3s0&amp;t=14e19e18" type="text/javascript"></script>
# <script src="/ScriptResource.axd?d=T1Zw-V2Vlul-37uRUeLVceV1bEq5fUYcbuYf_6e_PzTQAqyLDyjFATQU54odj7RvHbeekjbsF-J3jCqik8mErBHuuPNKDwsKDJwcGA9Ekqmp4chXhzZA-HTLtpsGfJJjexb-2GBnnpFcSSpxuTbq-g2&amp;t=ffffffffd8a61378" type="text/javascript"></script>
# <script src="/ScriptResource.axd?d=tJ5LdGIjpr-xT3942AgyLwbJH6l8FGao8uZzaon-U04tZOu0krWGJjH8PS896G87wcurA30B616ISlt5KL-YoO0HDWe42B98v_n1xqI6mNp55NEBc3lqD9C-r57EKdWz5gX5sr8qY3GYFy6BtINmMUhJc2IOEJ7cRVpDRyw2BrYsLDB2DdHB0DTyRWdAKztW0&amp;t=14e19e18" type="text/javascript"></script>
# <script src="/ScriptResource.axd?d=HoGBZkfbZbriHzwxTV32-96Bfl6IBhFbVfyRrraAvSu8prJ0-AA7OZRIPry_qLpcDUL9F0CjnLa-3NJaM9hBtWsyrVp0jCwakkHqoukhACmzSRw0KCAQYVfTxS5bQMS_PN3ZoqzVN_71VD1n9b_5DA2&amp;t=ffffffffd8a61378" type="text/javascript"></script>
# <script src="/ScriptResource.axd?d=FxmU7IrBmgPnlMezHjoZBaMKkUCJ0A9UHCdp0vTVB2EXxT_X7l8bBiM2aOAOoPq6Hs2S6RrnRrGv1f0V6pQs16zRnzerZZjrMY8Il_xSNnKxPhY7uVH5gST_3YClYsNb4kZ3RJX05fb09bUng7sr7A2&amp;t=ffffffffd8a61378" type="text/javascript"></script>
# <script src="/ScriptResource.axd?d=SX8XWlDBv42owXp8V9Mot4T3HxYtLN4VX9p1RVMuUV-FBMcFMtnDTiZ-16oFyYppIspZ2Zpd57RNU9yM2aAT7nelHNck2rkw31pBFXz9NZPMG41O8w6UvpaXSFd3wIeKNJs_ftMFp4CoZqHtyG74-wkphKhBX4clkw7kk4wnG_g1&amp;t=ffffffffd8a61378" type="text/javascript"></script>
# <script src="/ScriptResource.axd?d=TxnZ7bwWjHkbtXi5cK2Xojqs-DjSJ-AIeVLehF09U-iLetlJgCxoN90cz8F9cidZhazN_RWC5pSPJ1rGExnNzRYuhAnNgsslR-Pw2_Wwmunva9_kyi56vXe-VTdd3FWFehKghu6kOgFCuQg_F5YUDeJL57UjIdEZPB5V95i2tp41&amp;t=14e19e18" type="text/javascript"></script>
# <div class="cookdiv" id="CookDiv" style="display:none">
# <div class="InnerWrapper">
# <p class="cookp" style="z-index:999">Our site uses cookies. By continuing to use our site you are agreeing to our <a href="/cookie-policy">cookie policy. </a></p>
# <input class="DBS_Button DBS_Green" id="usrCtrl_Hide" name="ctl00$usrCtrl$Hide" onclick="createCookie('DBS','Accept Cookies',30);" style="margin: 10px; padding: 10px 25px !important;" type="submit" value="Accept and close"/>
# </div>
# </div>
# <script type="text/javascript">
#     function createCookie(name, value, day) {
#         var date = new Date();
#         date.setTime(date.getTime() + (day * 24 * 60 * 60 * 1000));
#         var expires = "; expires=" + date.toGMTString();
#         document.cookie = name + "=" + value + expires + "; path=/";
#     }
#     if (readCookie("DBS") == undefined) {
#         document.getElementById("CookDiv").style.display = "block"
#     }
#     else {
#         window.dataLayer.push({
#             'hasUserConsented': 'true',
#             'event': 'track_GAEventConsent'
#         });
#     }
#     function readCookie(name) {
#         var nameEQ = name + "=";
#         var ca = document.cookie.split(';');
#         for (var i = 0; i < ca.length; i++) {
#             var c = ca[i];
#             while (c.charAt(0) == ' ') c = c.substring(1, c.length);
#             if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length, c.length);
#         }
#         return null;
#     }
# </script>
# <!-- Google Tag Manager (noscript) -->
# <!-- End Google Tag Manager (noscript) -->
# <div id="mobile-indicator"></div>
# <div>
# <div class="sf_cols Header DBS_White">
# <div class="sf_colsOut sf_1col_1_100" style="">
# <div class="sf_colsIn sf_1col_1in_100" id="ContentPlaceHolder1_TB6148D1A001_Col00"><div class="sf_cols InnerWrapper">
# <div class="sf_colsOut sf_1col_1_100" style="">
# <div class="sf_colsIn sf_1col_1in_100" id="ContentPlaceHolder1_TB6148D1A003_Col00"><div class="sf_cols">
# <div class="sf_colsOut sf_2cols_1_25">
# <div class="sf_colsIn sf_2cols_1in_25" id="ContentPlaceHolder1_TB6148D1A021_Col00"><div class="sfContentBlock HomeLogo"><a href="/"><img alt="dbs-logo-2019" data-displaymode="Original" src="/images/default-source/logos/dbs-logo-2019-small.png" title="dbs-logo-2019"/></a>
# </div>
# </div>
# </div>
# <div class="sf_colsOut sf_2cols_2_75">
# <div class="sf_colsIn sf_2cols_2in_75" id="ContentPlaceHolder1_TB6148D1A021_Col01"><div class="sf_cols">
# <div class="sf_colsOut sf_2cols_1_25">
# <div class="sf_colsIn sf_2cols_1in_25" id="ContentPlaceHolder1_TB6148D1A056_Col00">
# </div>
# </div>
# <div class="sf_colsOut sf_2cols_2_75">
# <div class="sf_colsIn sf_2cols_2in_75" id="ContentPlaceHolder1_TB6148D1A056_Col01">
# <link href="/Frontend-Assembly/Telerik.Sitefinity.Frontend.Search/assets/dist/css/sf-search-box.min.css" rel="stylesheet" type="text/css"/>
# <div class="custom-search">
# <input id="796bd2f7-edf1-4ab4-a094-3e83daf8a990" placeholder="Search for a course" title="Search input" type="text" value=""/>
# <button id="b8bd1574-0745-4d9c-8801-484babe7d121" type="button">Search</button>
# <input data-sf-role="resultsUrl" type="hidden" value="/search-results"/>
# <input data-sf-role="indexCatalogue" type="hidden" value="searchindexv2"/>
# <input data-sf-role="wordsMode" type="hidden" value="AllWords"/>
# <input data-sf-role="disableSuggestions" type="hidden" value="false"/>
# <input data-sf-role="minSuggestionLength" type="hidden" value="2"/>
# <input data-sf-role="suggestionFields" type="hidden" value="Title,Content"/>
# <input data-sf-role="language" type="hidden"/>
# <input data-sf-role="suggestionsRoute" type="hidden" value="/restapi/search/suggestions"/>
# <input data-sf-role="searchTextBoxId" type="hidden" value="#796bd2f7-edf1-4ab4-a094-3e83daf8a990"/>
# <input data-sf-role="searchButtonId" type="hidden" value="#b8bd1574-0745-4d9c-8801-484babe7d121"/>
# </div>
# </div>
# </div>
# </div>
# <div class="sfContentBlock TopMenuContainer"><div class="TopGlobalMenu">
# <a href="https://www.dbs.ie/about-dbs/for-employers">Corporate Services</a> |
# <a href="https://library.dbs.ie">DBS Library</a> |
# <a href="https://www.dbs.ie/international-students">International Students</a> | <a href="https://students.dbs.ie">Current Students</a> | <a href="https://www.dbs.ie/news-and-events"></a><a href="https://www.dbs.ie/news-events">News &amp; Events</a> </div>
# </div>
# <script>
#     $(document).ready(function () {
#
#         $(".searchDiv").click(function () {
#             event.stopPropagation();
#             $(".GlobalSearchBox").toggle();
#             $(".GlobalSearchBox input").focus();
#         });
#
#         $(".GlobalSearchBox input").attr("placeholder", "Type and hit enter...");
#     });
# </script>
# <div>
# <div id="main_navigation">
# <ul id="menuroot">
# <li id="firstMenuItem"><a href="https://www.dbs.ie" title="Home">
# <img alt="Home" class="icon" src="/images/default-source/icons/home.png" title="Home"/></a></li>
# <li class="trigger">
# <a class='&lt;%# DataBinder.Eval(Container.DataItem, "CssStyle") %&gt; FirstLevelMenu' href="courses">Courses</a>
# <div class="SecondaryContainer">
# <ul class="menusecondlevel">
# <li>
# <a class="NavHeaderTopMenu">COURSES BY SUBJECT</a>
# </li>
# <li>
# <a href="courses/accounting-and-finance">Accounting &amp; Finance</a>
# </li>
# <li>
# <a href="courses/arts">Arts</a>
# </li>
# <li>
# <a href="courses/business-management">Business &amp; Management</a>
# </li>
# <li>
# <a href="courses/counselling-and-psychotherapy">Counselling &amp; Psychotherapy</a>
# </li>
# <li>
# <a href="courses/information-technology">Information Technology</a>
# </li>
# <li>
# <a href="courses/law">Law</a>
# </li>
# <li>
# <a href="courses/marketing-and-event-management">Marketing &amp; Event Management</a>
# </li>
# <li>
# <a href="courses/media-and-journalism">Media &amp; Journalism</a>
# </li>
# <li>
# <a href="courses/professional-accountancy">Professional Accountancy</a>
# </li>
# <li>
# <a href="courses/psychology-social-science">Psychology &amp; Social Science</a>
# </li>
# </ul>
# <ul class="menuaddlevel">
# <li>
# <a class="NavHeaderTopMenu">COURSES BY TYPE</a>
# </li>
# <li>
# <a href="courses/full-time-undergraduate">Full-time Degrees/ Certificates</a>
# </li>
# <li>
# <a href="courses/postgraduate">Postgraduate Programmes</a>
# </li>
# <li>
# <a href="courses/springboard">FREE* Springboard+ Programmes</a>
# </li>
# <li>
# <a href="courses/ict-skills-programme">FREE* ICT Skills Programmes</a>
# </li>
# <li>
# <a href="courses/evening-degree">Evening Degrees</a>
# </li>
# <li>
# <a href="courses/professional-accountancy">Professional Accountancy</a>
# </li>
# <li>
# <a href="courses/professional-evening-diploma">Professional Evening Diplomas</a>
# </li>
# <li>
# <a href="courses/international">International</a>
# </li>
# <li>
# <a href="courses/dbs-online">Online Courses at DBS</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="trigger">
# <a class='&lt;%# DataBinder.Eval(Container.DataItem, "CssStyle") %&gt; FirstLevelMenu' href="about-dbs">Why DBS</a>
# <div class="SecondaryContainer">
# <ul class="menusecondlevel">
# <li>
# <a class="NavHeaderTopMenu">WHY DBS</a>
# </li>
# <li>
# <a href="about-dbs/welcome">Welcome to Dublin Business School</a>
# </li>
# <li>
# <a href="about-dbs/history-of-dbs">History of DBS</a>
# </li>
# <li>
# <a href="about-dbs/academic-schools-staff">Academic School &amp; Staff</a>
# </li>
# <li>
# <a href="about-dbs/recognition-and-accreditation">Recognition &amp; Accreditation</a>
# </li>
# <li>
# <a href="advantage">DBS Advantage</a>
# </li>
# <li>
# <a href="about-dbs/for-employers">For Employers</a>
# </li>
# <li>
# <a href="about-dbs/for-guidance-counsellors">For Guidance Counsellors</a>
# </li>
# <li>
# <a href="about-dbs/kaplan-dublin-business-school">Kaplan businesses</a>
# </li>
# <li>
# <a href="about-dbs/jobs-dublin-business-school">Vacancies</a>
# </li>
# <li>
# <a href="about-dbs/hetac-institutional-review">HETAC Institutional Review</a>
# </li>
# <li>
# <a href="about-dbs/new-programmes-at-dbs">New programmes at DBS</a>
# </li>
# <li>
# <a href="about-dbs/dbs-esource">DBS eSource</a>
# </li>
# <li>
# <a href="about-dbs/news-and-events">News &amp; Events</a>
# </li>
# <li>
# <a href="about-dbs/why-dbs">Why DBS</a>
# </li>
# <li>
# <a href="about-dbs/links-with-industry">Links with Industry</a>
# </li>
# </ul>
# <ul class="menuaddlevel">
# <li>
# <a class="NavHeaderTopMenu">STUDENT EXPERIENCE</a>
# </li>
# <li>
# <a href="student-experience/student-services">Student Services</a>
# </li>
# <li>
# <a href="student-experience/student-life">Student Life</a>
# </li>
# <li>
# <a href="student-experience/clubs-societies">Clubs and Societies</a>
# </li>
# <li>
# <a href="student-experience/disabilities-support">Disability Support</a>
# </li>
# <li>
# <a href="student-experience/outstanding-facilities">Outstanding Facilities</a>
# </li>
# <li>
# <a href="student-experience/volunteer-at-dbs">Volunteer at DBS</a>
# </li>
# <li>
# <a href="student-experience/alumni">Alumni</a>
# </li>
# <li>
# <a href="student-experience/internationals">International Students</a>
# </li>
# <li>
# <a href="student-experience/employability">Employability</a>
# </li>
# <li>
# <a href="student-experience/careers">Careers</a>
# </li>
# <li>
# <a href="student-experience/learning-environment">Learning Environment</a>
# </li>
# <li>
# <a href="student-experience/student-testimonials">Student Testimonials</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="trigger">
# <a class='&lt;%# DataBinder.Eval(Container.DataItem, "CssStyle") %&gt; FirstLevelMenu' href="contact">Contact</a>
# <div class="SecondaryContainer">
# <ul class="menusecondlevel">
# <li>
# <a href="about-dbs/contact-us">Contact Information</a>
# </li>
# <li>
# <a href="about-dbs/location">DBS Locations</a>
# </li>
# <li>
# <a href="contact/order-a-prospectus">Order a Prospectus</a>
# </li>
# <li>
# <a href="contact-dbs/visit-dbs">Visit DBS</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="">
# <a class='&lt;%# DataBinder.Eval(Container.DataItem, "CssStyle") %&gt; FirstLevelMenu' href="enquiry/enquire-online">Enquiry</a>
# <div class="SecondaryContainer">
# <ul class="menusecondlevel">
# <li>
# <a class="NavHeaderTopMenu">ENQUIRY</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="">
# <a class='&lt;%# DataBinder.Eval(Container.DataItem, "CssStyle") %&gt; FirstLevelMenu' href="application-form">Apply</a>
# <div class="SecondaryContainer">
# <ul class="menusecondlevel">
# <li>
# <a class="NavHeaderTopMenu">APPLY</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="mobileOnly">
# <a href="https://students.dbs.ie">Current Students</a>
# <a href="/about-dbs/for-employers">Corporate Services</a>
# <a href="https://library.dbs.ie/">DBS Library</a>
# <a href="/news-events/">News &amp; Events</a>
# <a href="/International-students">International Students</a>
# </li>
# </ul>
# <div class="searchDiv" id="searchIconMag"></div>
# </div>
# </div>
# <div class="sf_cols SearchBoxContainer">
# <div class="sf_colsOut sf_1col_1_100">
# <div class="sf_colsIn sf_1col_1in_100" id="ContentPlaceHolder1_TB6148D1A042_Col00">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div><div class="sf_cols">
# <div class="sf_colsOut sf_1col_1_100">
# <div class="sf_colsIn sf_1col_1in_100" id="ContentPlaceHolder1_TB6148D1A059_Col00"><span id="ContentPlaceHolder1_TB6148D1A060_Label1"></span>
# </div>
# </div>
# </div><div class="sf_cols TopBanner">
# <div class="sf_colsOut sf_1col_1_100">
# <div class="sf_colsIn sf_1col_1in_100" id="ContentPlaceHolder1_TB6148D1A002_Col00"><div class="sf_cols InnerWrapper">
# <div class="sf_colsOut sf_1col_1_100" style="">
# <div class="sf_colsIn sf_1col_1in_100" id="ContentPlaceHolder1_TB6148D1A004_Col00"><div class="sfContentBlock"><h2 class="bannerH1"></h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div><div class="sf_cols CourseSearch DBS_LightGray">
# <div class="sf_colsOut sf_1col_1_100" style="">
# <div class="sf_colsIn sf_1col_1in_100" id="ContentPlaceHolder1_TB6148D1A005_Col00"><div class="sf_cols InnerWrapper CourseSearchDiv">
# <div class="sf_colsOut sf_1col_1_100" style="width: 100%;">
# <div class="sf_colsIn sf_1col_1in_100" id="ContentPlaceHolder1_TB6148D1A017_Col00">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div><div class="sf_cols">
# <div class="sf_colsOut sf_1col_1_100">
# <div class="sf_colsIn sf_1col_1in_100" id="ContentPlaceHolder1_TB6148D1A015_Col00"><div class="sf_cols InnerWrapper MobileWrapper">
# <div class="sf_colsOut sf_1col_1_100">
# <div class="sf_colsIn sf_1col_1in_100" id="ContentPlaceHolder1_TB6148D1A018_Col00"><div id="ContentPlaceHolder1_TB6148D1A055">
# <div class="sfBreadcrumbWrp">
# <span class="sfBreadcrumbLabel" id="ContentPlaceHolder1_TB6148D1A055_ctl00_ctl00_BreadcrumbLabel" style="display:none;"></span>
# <div class="RadSiteMap RadSiteMap_Default" id="ctl00_ContentPlaceHolder1_TB6148D1A055_ctl00_ctl00_Breadcrumb">
# <!-- 2017.3.913.40 --><ul class="rsmFlow rsmLevel rsmOneLevel">
# <li class="rsmItem sfBreadcrumbNavigation"><a class="rsmLink" href="home" title="Talk to us today! Dublin Business School is the largest independent third-level college in Ireland, offering a wide range of undergraduate, postgraduate and professional degree and masters courses. ">Home</a><span class="sfBreadcrumbNodeSeparator">/</span></li> <li class="rsmItem sfNoBreadcrumbNavigation"><a class="rsmLink" href="javascript: void(0)" title="News &amp; Events">News &amp; Events</a></li>
# </ul><input id="ctl00_ContentPlaceHolder1_TB6148D1A055_ctl00_ctl00_Breadcrumb_ClientState" name="ctl00_ContentPlaceHolder1_TB6148D1A055_ctl00_ctl00_Breadcrumb_ClientState" type="hidden"/>
# </div>
# </div>
# </div><div class="sf_cols">
# <div class="sf_colsOut sf_2cols_1_25 LayoutLeft" style="width: 30%;">
# <div class="sf_colsIn sf_2cols_1in_25" id="ContentPlaceHolder1_TB6148D1A034_Col00">
# <div class="sfNavWrp sfNavVerticalWrp">
# <a class="sfNavToggle" id="ContentPlaceHolder1_TB6148D1A035_ctl00_ctl00_ctl01_ctl00_ctl00_toggleAnchor">Menu</a>
# <script type="text/javascript">
#     (function ($) {
#         $($get('ContentPlaceHolder1_TB6148D1A035_ctl00_ctl00_ctl01_ctl00_ctl00_toggleAnchor')).click(function () {
#             $(this).closest(".sfNavWrp").find(".sfNavList").toggleClass("sfShown");
#         });
#     })(jQuery);
# </script>
# <ul class="sfNavVertical sfNavList VerticalNavCustom">
# <li>
# <a href="/about-dbs/welcome">Welcome to Dublin Business School</a>
# </li>
# <li>
# <a href="/about-dbs/history-of-dbs">History of DBS</a>
# </li>
# <li>
# <a href="/about-dbs/academic-schools-staff">Academic School &amp; Staff</a>
# </li>
# <li>
# <a href="/about-dbs/recognition-and-accreditation">Recognition &amp; Accreditation</a>
# </li>
# <li>
# <a href="/advantage">DBS Advantage</a>
# </li>
# <li>
# <a href="/about-dbs/for-employers">For Employers</a>
# </li>
# <li>
# <a href="/about-dbs/for-guidance-counsellors">For Guidance Counsellors</a>
# </li>
# <li>
# <a href="/about-dbs/kaplan-dublin-business-school">Kaplan businesses</a>
# </li>
# <li>
# <a href="/about-dbs/jobs-dublin-business-school">Vacancies</a>
# </li>
# <li>
# <a href="/about-dbs/hetac-institutional-review">HETAC Institutional Review</a>
# </li>
# <li>
# <a href="/about-dbs/new-programmes-at-dbs">New programmes at DBS</a>
# </li>
# <li>
# <a href="/about-dbs/dbs-esource">DBS eSource</a>
# </li>
# <li>
# <a href="/about-dbs/why-dbs">Why DBS</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="sf_colsOut sf_2cols_2_75 LayoutRight" style="width: 70%;">
# <div class="sf_colsIn sf_2cols_2in_75" id="ContentPlaceHolder1_TB6148D1A034_Col01"><div class="sf_cols">
# <div class="sf_colsOut sf_1col_1_100">
# <div class="sf_colsIn sf_1col_1in_100" id="ContentPlaceHolder1_C006_Col00">
# </div>
# </div>
# </div><div class="sfContentBlock"><h2 style="font-size:30px;text-transform:uppercase;font-weight:400;">News and Events</h2>
# </div><div class="custom-single-news-item" id="ContentPlaceHolder1_C003">
# <ul class="sfnewsList sfnewsListTitleDateSummary sflist">
# <label id="monthinput"></label>
# <div class="NewsWrapper">
# <div class="sfMultiRelatedItmsWrp_left">
# <h4 class="sfrelatedItmTitle"></h4>
# <ul class="sfrelatedList sflist">
# <li class="sfrelatedListItem sflistitem">
# <a href="https://www.dbs.ie/images/default-source/default-album/img_20190906_155501-(1)fdd4042a53ff6d7ebe9cff000003f2be.jpg?sfvrsn=5a2b69ea_0">
# <img alt="IMG_20190906_155501 (1)" class="NewsImg" src="https://www.dbs.ie/images/default-source/default-album/img_20190906_155501-(1)fdd4042a53ff6d7ebe9cff000003f2be.tmb-.jpg?sfvrsn=5a2b69ea_1" title="IMG_20190906_155501 (1)"/>
# </a>
# </li>
# </ul>
# </div>
# <div class="NewsEvent_right">
# <li class="sfnewsListItem sflistitem" data-sf-id="75ef042a-53ff-6d7e-be9c-ff000003f2be" data-sf-provider="OpenAccessDataProvider" data-sf-type="Telerik.Sitefinity.News.Model.NewsItem">
# <div class="DateWrapper">
# 		Friday, September 13, 2019
# 	</div>
# <a class="newsTitle" data-sf-field="Title" data-sf-ftype="ShortText" href="about-dbs/news-and-events/2019/09/13/why-we-respond-and-why-we-turn-away-human-rights-abuses-in-a-changing-world">‘Why We Respond and Why We Turn Away: Human Rights Abuses in a Changing World’</a>
# <br/>
# <div class="sfnewsSummary sfsummary" data-sf-field="Summary" data-sf-ftype="ShortText">
# 		DBS recently held a psychology conference, entitled ‘Why We Respond and Why We Turn Away: Human Rights Abuses in a Changing World’. The event explored factors underlying human responses to the plight of others.
# 	</div>
# <a class="sfnewsFullStory sffullstory" href="about-dbs/news-and-events/2019/09/13/why-we-respond-and-why-we-turn-away-human-rights-abuses-in-a-changing-world" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl0_FullStory">Full story</a>
# <div class="HideListCategory" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl0_HierarchicalFieldControl">
# </div>
# </li>
# </div>
# </div>
# <label id="monthinput"></label>
# <div class="NewsWrapper">
# <div class="sfMultiRelatedItmsWrp_left">
# <h4 class="sfrelatedItmTitle"></h4>
# <ul class="sfrelatedList sflist">
# <li class="sfrelatedListItem sflistitem">
# <a href="https://www.dbs.ie/images/default-source/default-album/fintech-breakfast-briefing-poster-(1)6c99042a53ff6d7ebe9cff000003f2be.jpg?sfvrsn=c96669ea_0">
# <img alt="FinTech Breakfast Briefing Poster (1)" class="NewsImg" src="https://www.dbs.ie/images/default-source/default-album/fintech-breakfast-briefing-poster-(1)6c99042a53ff6d7ebe9cff000003f2be.tmb-.jpg?sfvrsn=c96669ea_1" title="FinTech Breakfast Briefing Poster (1)"/>
# </a>
# </li>
# </ul>
# </div>
# <div class="NewsEvent_right">
# <li class="sfnewsListItem sflistitem" data-sf-id="7d99042a-53ff-6d7e-be9c-ff000003f2be" data-sf-provider="OpenAccessDataProvider" data-sf-type="Telerik.Sitefinity.News.Model.NewsItem">
# <div class="DateWrapper">
# 		Friday, August 30, 2019
# 	</div>
# <a class="newsTitle" data-sf-field="Title" data-sf-ftype="ShortText" href="about-dbs/news-and-events/2019/08/30/fintech-breakfast-briefing-with-daniel-broby">FinTech Breakfast Briefing with Daniel Broby</a>
# <br/>
# <div class="sfnewsSummary sfsummary" data-sf-field="Summary" data-sf-ftype="ShortText">
# 		DBS FinTech Society presents A Breakfast Briefing, 'Introducing Strategic FinTech' with Daniel Broby; Director for Centre of Financial Regulation &amp; Innovation at Strathclyde Business School.
# 	</div>
# <a class="sfnewsFullStory sffullstory" href="about-dbs/news-and-events/2019/08/30/fintech-breakfast-briefing-with-daniel-broby" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl1_FullStory">Full story</a>
# <div class="HideListCategory" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl1_HierarchicalFieldControl">
# </div>
# </li>
# </div>
# </div>
# <label id="monthinput"></label>
# <div class="NewsWrapper">
# <div class="sfMultiRelatedItmsWrp_left">
# <h4 class="sfrelatedItmTitle"></h4>
# <ul class="sfrelatedList sflist">
# <li class="sfrelatedListItem sflistitem">
# <a href="https://www.dbs.ie/images/default-source/default-album/john-mcdonnell-testimonial-imageac81042a53ff6d7ebe9cff000003f2be.png?sfvrsn=97e69ea_0">
# <img alt="John McDonnell Testimonial Image" class="NewsImg" src="https://www.dbs.ie/images/default-source/default-album/john-mcdonnell-testimonial-imageac81042a53ff6d7ebe9cff000003f2be.tmb-.png?sfvrsn=97e69ea_1" title="John McDonnell Testimonial Image"/>
# </a>
# </li>
# </ul>
# </div>
# <div class="NewsEvent_right">
# <li class="sfnewsListItem sflistitem" data-sf-id="4a94042a-53ff-6d7e-be9c-ff000003f2be" data-sf-provider="OpenAccessDataProvider" data-sf-type="Telerik.Sitefinity.News.Model.NewsItem">
# <div class="DateWrapper">
# 		Thursday, August 29, 2019
# 	</div>
# <a class="newsTitle" data-sf-field="Title" data-sf-ftype="ShortText" href="about-dbs/news-and-events/2019/08/29/student-testimonial-john-mcdonnell-hdip-in-science-in-data-analytics">Student Testimonial: John McDonnell, HDip in Science in Data Analytics</a>
# <br/>
# <div class="sfnewsSummary sfsummary" data-sf-field="Summary" data-sf-ftype="ShortText">
# 		John McDonnell is a graduate of the Higher Diploma in Science in Data Analytics programme here at DBS. We caught up with John to ask him about his experience with the course and here is what he had to say...
# 	</div>
# <a class="sfnewsFullStory sffullstory" href="about-dbs/news-and-events/2019/08/29/student-testimonial-john-mcdonnell-hdip-in-science-in-data-analytics" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl2_FullStory">Full story</a>
# <div class="HideListCategory" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl2_HierarchicalFieldControl">
# </div>
# </li>
# </div>
# </div>
# <label id="monthinput"></label>
# <div class="NewsWrapper">
# <div class="sfMultiRelatedItmsWrp_left">
# <h4 class="sfrelatedItmTitle"></h4>
# <ul class="sfrelatedList sflist">
# <li class="sfrelatedListItem sflistitem">
# <a href="https://www.dbs.ie/images/default-source/default-album/screen-grab-fintech9997042a53ff6d7ebe9cff000003f2be.jpg?sfvrsn=3e6869ea_0">
# <img alt="Screen Grab FinTech" class="NewsImg" src="https://www.dbs.ie/images/default-source/default-album/screen-grab-fintech9997042a53ff6d7ebe9cff000003f2be.tmb-.jpg?sfvrsn=3e6869ea_1" title="Screen Grab FinTech"/>
# </a>
# </li>
# </ul>
# </div>
# <div class="NewsEvent_right">
# <li class="sfnewsListItem sflistitem" data-sf-id="0c84042a-53ff-6d7e-be9c-ff000003f2be" data-sf-provider="OpenAccessDataProvider" data-sf-type="Telerik.Sitefinity.News.Model.NewsItem">
# <div class="DateWrapper">
# 		Monday, August 26, 2019
# 	</div>
# <a class="newsTitle" data-sf-field="Title" data-sf-ftype="ShortText" href="about-dbs/news-and-events/2019/08/26/dbs-fintech-breakfast-briefings-series"> DBS Fintech Breakfast Briefings Series</a>
# <br/>
# <div class="sfnewsSummary sfsummary" data-sf-field="Summary" data-sf-ftype="ShortText">
# 		DBS FinTech Breakfast Briefings series - this week, Alan O'Sullivan from Aviva Insurance hosted the morning briefing and discussed a range of subjects, including asset allocation, modern portfolio theory, risk management and behavioural finance.
# 	</div>
# <a class="sfnewsFullStory sffullstory" href="about-dbs/news-and-events/2019/08/26/dbs-fintech-breakfast-briefings-series" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl3_FullStory">Full story</a>
# <div class="HideListCategory" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl3_HierarchicalFieldControl">
# </div>
# </li>
# </div>
# </div>
# <label id="monthinput"></label>
# <div class="NewsWrapper">
# <div class="sfMultiRelatedItmsWrp_left">
# <h4 class="sfrelatedItmTitle"></h4>
# <ul class="sfrelatedList sflist">
# <li class="sfrelatedListItem sflistitem">
# <a href="https://www.dbs.ie/images/default-source/default-album/susan-yin-2jivbogleho-unsplash.jpg?sfvrsn=f28969ea_0">
# <img alt="susan-yin-2JIvboGLeho-unsplash" class="NewsImg" src="https://www.dbs.ie/images/default-source/default-album/susan-yin-2jivbogleho-unsplash.tmb-.jpg?sfvrsn=f28969ea_1" title="susan-yin-2JIvboGLeho-unsplash"/>
# </a>
# </li>
# </ul>
# </div>
# <div class="NewsEvent_right">
# <li class="sfnewsListItem sflistitem" data-sf-id="b577042a-53ff-6d7e-be9c-ff000003f2be" data-sf-provider="OpenAccessDataProvider" data-sf-type="Telerik.Sitefinity.News.Model.NewsItem">
# <div class="DateWrapper">
# 		Thursday, August 22, 2019
# 	</div>
# <a class="newsTitle" data-sf-field="Title" data-sf-ftype="ShortText" href="about-dbs/news-and-events/2019/08/22/5-part-time-courses-that-could-kick-start-your-career-in-2019-dbs">5 Part-Time Courses That Could Kick-start Your Career in 2019| DBS</a>
# <br/>
# <div class="sfnewsSummary sfsummary" data-sf-field="Summary" data-sf-ftype="ShortText">
# 		Whether you are looking to progress your current career or switch gears entirely – DBS offers an array of part-time evening courses designed to accommodate a working lifestyle; providing a flexible pathway to learning. We picked five DBS part-time courses to kick-start your studies in 2019.
# 	</div>
# <a class="sfnewsFullStory sffullstory" href="about-dbs/news-and-events/2019/08/22/5-part-time-courses-that-could-kick-start-your-career-in-2019-dbs" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl4_FullStory">Full story</a>
# <div class="HideListCategory" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl4_HierarchicalFieldControl">
# </div>
# </li>
# </div>
# </div>
# </ul>
# <input id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ClientState" name="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ClientState" type="hidden"/><span id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList" style="display:none;"></span>
# <div id="ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_pager">
# <div class="sf_pagerNumeric" id="ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_pager_ctl00_ctl00_numeric"><a class="sf_PagerCurrent" href="https://www.dbs.ie/about-dbs/news-and-events">1</a><a href="https://www.dbs.ie/about-dbs/news-and-events/page/2">2</a><a href="https://www.dbs.ie/about-dbs/news-and-events/page/3">3</a><a href="https://www.dbs.ie/about-dbs/news-and-events/page/4">4</a><a href="https://www.dbs.ie/about-dbs/news-and-events/page/5">5</a><a href="https://www.dbs.ie/about-dbs/news-and-events/page/6">6</a><a href="https://www.dbs.ie/about-dbs/news-and-events/page/7">7</a><a href="https://www.dbs.ie/about-dbs/news-and-events/page/8">8</a><a href="https://www.dbs.ie/about-dbs/news-and-events/page/9">9</a><a href="https://www.dbs.ie/about-dbs/news-and-events/page/10">10</a><a class="sf_PagerNextGroup" href="https://www.dbs.ie/about-dbs/news-and-events/page/11">...</a></div>
# </div>
# <span></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div><div class="sf_cols Footer DBS_Gray">
# <div class="sf_colsOut sf_1col_1_100" style="">
# <div class="sf_colsIn sf_1col_1in_100" id="ContentPlaceHolder1_TB6148D1A016_Col00"><div class="sf_cols InnerWrapper">
# <div class="sf_colsOut sf_1col_1_100" style="width: 100%;">
# <div class="sf_colsIn sf_1col_1in_100" id="ContentPlaceHolder1_TB6148D1A019_Col00"><div class="sf_cols">
# <div class="sf_colsOut sf_4cols_1_25 Footer_About">
# <div class="sf_colsIn sf_4cols_1in_25" id="ContentPlaceHolder1_TB6148D1A025_Col00"><div class="sfContentBlock Footer_Header"><p><strong>ABOUT DBS</strong></p>
# </div>
# <div class="sfNavWrp sfNavVerticalWrp FooterContent">
# <a class="sfNavToggle" id="ContentPlaceHolder1_TB6148D1A038_ctl00_ctl00_ctl01_ctl00_ctl00_toggleAnchor">Menu</a>
# <script type="text/javascript">
#     (function ($) {
#         $($get('ContentPlaceHolder1_TB6148D1A038_ctl00_ctl00_ctl01_ctl00_ctl00_toggleAnchor')).click(function () {
#             $(this).closest(".sfNavWrp").find(".sfNavList").toggleClass("sfShown");
#         });
#     })(jQuery);
# </script>
# <ul class="sfNavVertical sfNavList">
# <li>
# <a href="/about-dbs/welcome">Welcome to Dublin Business School</a>
# </li>
# <li>
# <a href="/about-dbs/history-of-dbs">History of DBS</a>
# </li>
# <li>
# <a href="/about-dbs/academic-schools-staff">Academic School &amp; Staff</a>
# </li>
# <li>
# <a href="/about-dbs/recognition-and-accreditation">Recognition &amp; Accreditation</a>
# </li>
# <li>
# <a href="/advantage">DBS Advantage</a>
# </li>
# <li>
# <a href="/about-dbs/for-employers">For Employers</a>
# </li>
# <li>
# <a href="/about-dbs/for-guidance-counsellors">For Guidance Counsellors</a>
# </li>
# <li>
# <a href="/about-dbs/kaplan-dublin-business-school">Kaplan businesses</a>
# </li>
# <li>
# <a href="/about-dbs/jobs-dublin-business-school">Vacancies</a>
# </li>
# <li>
# <a href="/about-dbs/hetac-institutional-review">HETAC Institutional Review</a>
# </li>
# <li>
# <a href="/about-dbs/new-programmes-at-dbs">New programmes at DBS</a>
# </li>
# <li>
# <a href="/about-dbs/dbs-esource">DBS eSource</a>
# </li>
# <li>
# <a href="/about-dbs/why-dbs">Why DBS</a>
# </li>
# </ul>
# </div>
# <div class="sfContentBlock FooterContent"><li><a href="/international-students">International Students</a></li>
# <li>
# <a href="/terms-and-conditions">Terms and Conditions</a>
# </li>
# <li>
# <a href="/privacy-policy">Privacy Policy</a></li>
# <li><a href="/cookie-policy">Cookie Policy</a></li>
# <li>
# <a href="/company-registration-details">Company Registration Details</a> </li>
# </div>
# </div>
# </div>
# <div class="sf_colsOut sf_4cols_2_25 Footer_DBS">
# <div class="sf_colsIn sf_4cols_2in_25" id="ContentPlaceHolder1_TB6148D1A025_Col01"><div class="sfContentBlock Footer_Header"><p><strong>COURSES BY SUBJECT</strong></p>
# </div><div class="sfContentBlock FooterContent"><li><a href="https://www.dbs.ie/courses/accounting-and-finance">Accounting and Finance</a></li>
# <li><a href="https://www.dbs.ie/courses/arts">Arts</a></li>
# <li><a href="https://www.dbs.ie/courses/business-management">Business and Management</a></li>
# <li><a href="https://www.dbs.ie/courses/counselling-and-psychotherapy">Counselling and Psychotherapy</a></li>
# <li><a href="https://www.dbs.ie/courses/information-technology">Information Technology</a></li>
# <li><a href="https://www.dbs.ie/courses/law">Law</a></li>
# <li><a href="https://www.dbs.ie/courses/marketing-and-event-management">Marketing and Event Management</a></li>
# <li><a href="https://www.dbs.ie/courses/media-and-journalism">Media and Journalism</a></li>
# <li><a href="https://www.dbs.ie/courses/professional-accountancy">Professional Accountancy</a></li>
# <li><a href="https://www.dbs.ie/courses/psychology-social-science">Psychology and Social Science</a></li>
# </div>
# </div>
# </div>
# <div class="sf_colsOut sf_4cols_3_25 Footer_Student">
# <div class="sf_colsIn sf_4cols_3in_25" id="ContentPlaceHolder1_TB6148D1A025_Col02"><div class="sfContentBlock Footer_Header"><p><strong>​COURSES BY TYPE</strong></p>
# </div><div class="sfContentBlock FooterContent"><li><a href="https://www.dbs.ie/courses/evening-degree">Evening Degrees</a></li>
# <li><a href="https://www.dbs.ie/courses/full-time-undergraduate">Full-time Degrees / Certificates</a></li>
# <li><a href="https://www.dbs.ie/courses/ict-skills-programme">ICT Skills Programme</a></li>
# <li><a href="https://www.dbs.ie/courses/postgraduate">Postgraduate Courses</a> </li>
# <li><a href="https://www.dbs.ie/courses/professional-accountancy">Professional Accountancy</a></li>
# <li><a href="https://www.dbs.ie/courses/professional-evening-diploma">Professional Evening Diplomas</a></li>
# <li><a href="https://www.dbs.ie/courses/springboard">Springboard+</a></li>
# <li><a href="https://www.dbs.ie/course/online-courses">DBS Online Courses</a></li>
# </div><div class="sfContentBlock Footer_Header"><p><strong>STUDENT RESOURCES</strong></p>
# </div><div class="sfContentBlock FooterContent"><li><a href="https://library.dbs.ie">DBS Library</a></li>
# <li><a href="/student-experience">Student Services</a></li>
# <li><a href="/student-experience/careers">Careers</a></li>
# <li><a href="https://students.dbs.ie/registrar-office">Registrar's office</a></li>
# <li><a href="https://students.dbs.ie/exams-office">Exam office</a></li>
# </div>
# </div>
# </div>
# <div class="sf_colsOut sf_4cols_4_25 Footer_Kaplan">
# <div class="sf_colsIn sf_4cols_4in_25" id="ContentPlaceHolder1_TB6148D1A025_Col03"><div class="sfContentBlock Footer_Header"><p><strong>​DUBLIN BUSINESS SCHOOL</strong></p>
# </div><div class="sfContentBlock FooterContent"><div class="FooterCol4" style="text-align: right;">
# 13/14 Aungier Street,<br/>
# Dublin 2,<br/>
# Ireland.<br/>
# <br/>
# T: +353 1 417 7500<br/>
# E: <a href="mailto:admissions@dbs.ie">admissions@dbs.ie</a><br/>
# <br/>
# <br/>
# <img alt="kaplan-logo-footer" displaymode="Original" src="/images/default-source/logos/kaplan-logo-footer.png?sfvrsn=1530a0e9_2" style="float: left;" title="kaplan-logo-footer"/><br/>
# <br/>
#  DBS is part of KAPLAN INC.<br/>
# provider of Education Services
# </div>
# </div><div class="sfContentBlock FooterContent"><div id="FooterIcons" style="float: right;">
# <a class="SocialTwitter" href="https://twitter.com/dbscollege" style="float: left; width: 40px; height: 40px; background: url('/images/default-source/social-icons/twitter.png?sfvrsn=8') 0% 0% repeat scroll transparent;"></a>
# <a class="SocialFB" href="https://www.facebook.com/DublinBusinessSchool" style="float: left; width: 40px; height: 40px; background: url('/images/default-source/social-icons/fb.png?sfvrsn=8') 0% 0% repeat scroll transparent;"></a>
# <a class="SocialGP" href="https://plus.google.com/104823954619043738289/about" style="float: left; width: 40px; height: 40px; background: url('/images/default-source/social-icons/gplus.png?sfvrsn=8') 0% 0% repeat scroll transparent;"></a>
# <a class="SocialInstagram" href="https://instagram.com/dbscollege/" style="float: left; width: 40px; height: 40px; background: url('/images/default-source/social-icons/insta.png?sfvrsn=2') 0% 0% repeat scroll transparent;"></a></div>
# </div>
# </div>
# </div>
# </div><div class="sf_cols">
# <div class="sf_colsOut sf_2cols_1_50">
# <div class="sf_colsIn sf_2cols_1in_50" id="ContentPlaceHolder1_TB6148D1A026_Col00">
# </div>
# </div>
# <div class="sf_colsOut sf_2cols_2_50">
# <div class="sf_colsIn sf_2cols_2in_50" id="ContentPlaceHolder1_TB6148D1A026_Col01"><div class="sfContentBlock FooterCopyright FooterContent"><div style="float: right;">© <span class="copy"></span>, Dublin Business School</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>(function (i, s, o, g, r, a, m) {
# i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
# (i[r].q = i[r].q || []).push(arguments)
# }, i[r].l = 1 * new Date(); a = s.createElement(o),
# m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
# })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
# ga('create', 'UA-6683088-9', 'dbs.ie');
# ga('send', 'pageview');
# var $viewport = $('head meta[name="viewport"]');
# $viewport.attr('content', 'width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no');
# document.body.style.opacity = .9999;
# setTimeout(function () {
# document.body.style.opacity = 1;
# }, 1);
# </script>
# <script type="text/javascript">
#             $(function () {
#
#                 var page = window.location.pathname;
#                 var spliturl = [];
#                 spliturl = page.split("/")
#
#                 var currentPageUrlIs = spliturl[1];
#                 var headerTitle;
#
#                 switch (currentPageUrlIs) {
#
#                     case 'courses':
#                         $(".TopBanner").addClass("courses_banner");
#                         $(".TopBanner").removeClass("TopBanner");
#                         break;
#                     case 'about-dbs':
#
#                         $(".TopBanner").addClass("why-dbs_banner");
#                         $(".TopBanner").removeClass("TopBanner");
#
#                         headerTitle = 'About DBS';
#
#                         break;
#                     case 'contact-dbs':
#                         $(".TopBanner").addClass("contact_banner");
#                         $(".TopBanner").removeClass("TopBanner");
#                         headerTitle = 'Contact DBS';
#
#                         break;
#                     case 'student-experience':
#                         $(".TopBanner").addClass("student-experience_banner");
#                         $(".TopBanner").removeClass("TopBanner");
#
#                         headerTitle = 'Student Experience';
#
#                         break;
#                     case 'contact':
#                         $(".TopBanner").addClass("contact_banner");
#                         $(".TopBanner").removeClass("TopBanner");
#                         headerTitle = 'Contact';
#
#                         break;
#                     case 'news-and-events':
#                         $(".TopBanner").addClass("News-Events_banner");
#                         $(".TopBanner").removeClass("TopBanner");
#                         headerTitle = "News Events";
#                         break;
#                     case 'application-form':
#                         $(".TopBanner").addClass("apply_banner");
#                         $(".TopBanner").removeClass("TopBanner");
#                         headerTitle = "Apply";
#                         break;
#                     case 'dbs-online':
#                         $(".TopBanner").addClass("apply_banner");
#                         $(".TopBanner").removeClass("TopBanner");
#                         headerTitle = "DBS Online Courses";
#                         break;
#                     case 'enquirysubmitted':
#                         $(".TopBanner").addClass("TopBanner");
#                         headerTitle = "Enquiry Submitted";
#                         break;
#                     default:
#                         $(this).addClass("TopBanner");
#
#                         if (currentPageUrlIs != "course") {
#
#                             headerTitle = currentPageUrlIs;
#                         }
#                         else if (spliturl[2] == "online-courses") {
#                             headerTitle = "Our Online Courses";
#                         }
#
#                         if (headerTitle != null) {
#                             headerTitle = headerTitle.replace(/-/g, " ").replace(/\w\S*/g, function (txt) { return txt.charAt(0).toUpperCase() + txt.substr(1).toLowerCase(); });
#                         }
#                         break;
#                 }
#
#                 if (headerTitle != null) {
#                     if (!$(".subjectAreaBC")[0] || spliturl[2] == "online-courses") {
#                         $(".bannerH1:eq(0)").html(headerTitle);
#                     }
#                 }
#
#             });
#
#
#
#             function showResMenu() {
#
#                 $('.MainNavigation').css('display', 'block');
#
#             }
#         </script>
# <script src="/Javascript/global.js" type="text/javascript"></script>
# <!--	<span id="HostName">WEB01-CA-SVR01</span>-->
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="1730C157"/>
# <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="/wEdAALTZmVHqoWjqIaohG6fdkDxm+NLBbuPgpnWJr+Z3b04yWNXr6OG1cn3iPQik1hYHOBq42PFQ4qg1n3tZzVlQb90"/>
# </div>
# <script type="text/javascript">
# //<![CDATA[
# ;(function() {
#                         function loadHandler() {
#                             var hf = $get('ctl08_TSSM');
#                             if (!hf._RSSM_init) { hf._RSSM_init = true; hf.value = ''; }
#                             hf.value += ';Telerik.Sitefinity.Resources, Version=10.2.6626.0, Culture=neutral, PublicKeyToken=b28c218413bdf563:en:75ec3a6b-4122-4e56-a1f4-58f0be0d90a0:7a90d6a;Telerik.Sitefinity.Resources, Version=10.2.6626.0, Culture=neutral, PublicKeyToken=b28c218413bdf563:en:75ec3a6b-4122-4e56-a1f4-58f0be0d90a0:83fa35c7';
#                             Sys.Application.remove_load(loadHandler);
#                         };
#                         Sys.Application.add_load(loadHandler);
#                     })();Sys.Application.add_init(function() {
#     $create(Telerik.Web.UI.RadSiteMap, null, null, null, $get("ctl00_ContentPlaceHolder1_TB6148D1A055_ctl00_ctl00_Breadcrumb"));
# });
# Sys.Application.add_init(function() {
#     $create(Telerik.Web.UI.RadListView, {"UniqueID":"ctl00$ContentPlaceHolder1$C003$newsFrontendList$ctl00$ctl00$NewsList","_clientSettings":{"DataBinding":{"ItemPlaceHolderID":"ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ItemsContainer","DataService":{}}},"_virtualItemCount":5,"clientStateFieldID":"ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ClientState","renderMode":1}, null, null, $get("ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList"));
# });
# Sys.Application.add_init(function() {
#     $create(Telerik.Sitefinity.Web.UI.UserPreferences, {"_timeOffset":"3600000","_userBrowserSettingsForCalculatingDates":true,"timeZoneDisplayName":"(UTC+00:00) Dublin, Edinburgh, Lisbon, London","timeZoneId":"GMT Standard Time"}, null, null);
# });
# //]]>
# </script>
# </form>
# </body>
# </html>

# %%
# Finding each events
article = page_soup.findAll('li',class_='sfnewsListItem sflistitem')
print(article)
# Out:
# [<li class="sfnewsListItem sflistitem" data-sf-id="75ef042a-53ff-6d7e-be9c-ff000003f2be" data-sf-provider="OpenAccessDataProvider" data-sf-type="Telerik.Sitefinity.News.Model.NewsItem">
# <div class="DateWrapper">
# 		Friday, September 13, 2019
# 	</div>
# <a class="newsTitle" data-sf-field="Title" data-sf-ftype="ShortText" href="about-dbs/news-and-events/2019/09/13/why-we-respond-and-why-we-turn-away-human-rights-abuses-in-a-changing-world">‘Why We Respond and Why We Turn Away: Human Rights Abuses in a Changing World’</a>
# <br/>
# <div class="sfnewsSummary sfsummary" data-sf-field="Summary" data-sf-ftype="ShortText">
# 		DBS recently held a psychology conference, entitled ‘Why We Respond and Why We Turn Away: Human Rights Abuses in a Changing World’. The event explored factors underlying human responses to the plight of others.
# 	</div>
# <a class="sfnewsFullStory sffullstory" href="about-dbs/news-and-events/2019/09/13/why-we-respond-and-why-we-turn-away-human-rights-abuses-in-a-changing-world" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl0_FullStory">Full story</a>
# <div class="HideListCategory" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl0_HierarchicalFieldControl">
# </div>
# </li>, <li class="sfnewsListItem sflistitem" data-sf-id="7d99042a-53ff-6d7e-be9c-ff000003f2be" data-sf-provider="OpenAccessDataProvider" data-sf-type="Telerik.Sitefinity.News.Model.NewsItem">
# <div class="DateWrapper">
# 		Friday, August 30, 2019
# 	</div>
# <a class="newsTitle" data-sf-field="Title" data-sf-ftype="ShortText" href="about-dbs/news-and-events/2019/08/30/fintech-breakfast-briefing-with-daniel-broby">FinTech Breakfast Briefing with Daniel Broby</a>
# <br/>
# <div class="sfnewsSummary sfsummary" data-sf-field="Summary" data-sf-ftype="ShortText">
# 		DBS FinTech Society presents A Breakfast Briefing, 'Introducing Strategic FinTech' with Daniel Broby; Director for Centre of Financial Regulation &amp; Innovation at Strathclyde Business School.
# 	</div>
# <a class="sfnewsFullStory sffullstory" href="about-dbs/news-and-events/2019/08/30/fintech-breakfast-briefing-with-daniel-broby" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl1_FullStory">Full story</a>
# <div class="HideListCategory" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl1_HierarchicalFieldControl">
# </div>
# </li>, <li class="sfnewsListItem sflistitem" data-sf-id="4a94042a-53ff-6d7e-be9c-ff000003f2be" data-sf-provider="OpenAccessDataProvider" data-sf-type="Telerik.Sitefinity.News.Model.NewsItem">
# <div class="DateWrapper">
# 		Thursday, August 29, 2019
# 	</div>
# <a class="newsTitle" data-sf-field="Title" data-sf-ftype="ShortText" href="about-dbs/news-and-events/2019/08/29/student-testimonial-john-mcdonnell-hdip-in-science-in-data-analytics">Student Testimonial: John McDonnell, HDip in Science in Data Analytics</a>
# <br/>
# <div class="sfnewsSummary sfsummary" data-sf-field="Summary" data-sf-ftype="ShortText">
# 		John McDonnell is a graduate of the Higher Diploma in Science in Data Analytics programme here at DBS. We caught up with John to ask him about his experience with the course and here is what he had to say...
# 	</div>
# <a class="sfnewsFullStory sffullstory" href="about-dbs/news-and-events/2019/08/29/student-testimonial-john-mcdonnell-hdip-in-science-in-data-analytics" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl2_FullStory">Full story</a>
# <div class="HideListCategory" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl2_HierarchicalFieldControl">
# </div>
# </li>, <li class="sfnewsListItem sflistitem" data-sf-id="0c84042a-53ff-6d7e-be9c-ff000003f2be" data-sf-provider="OpenAccessDataProvider" data-sf-type="Telerik.Sitefinity.News.Model.NewsItem">
# <div class="DateWrapper">
# 		Monday, August 26, 2019
# 	</div>
# <a class="newsTitle" data-sf-field="Title" data-sf-ftype="ShortText" href="about-dbs/news-and-events/2019/08/26/dbs-fintech-breakfast-briefings-series"> DBS Fintech Breakfast Briefings Series</a>
# <br/>
# <div class="sfnewsSummary sfsummary" data-sf-field="Summary" data-sf-ftype="ShortText">
# 		DBS FinTech Breakfast Briefings series - this week, Alan O'Sullivan from Aviva Insurance hosted the morning briefing and discussed a range of subjects, including asset allocation, modern portfolio theory, risk management and behavioural finance.
# 	</div>
# <a class="sfnewsFullStory sffullstory" href="about-dbs/news-and-events/2019/08/26/dbs-fintech-breakfast-briefings-series" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl3_FullStory">Full story</a>
# <div class="HideListCategory" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl3_HierarchicalFieldControl">
# </div>
# </li>, <li class="sfnewsListItem sflistitem" data-sf-id="b577042a-53ff-6d7e-be9c-ff000003f2be" data-sf-provider="OpenAccessDataProvider" data-sf-type="Telerik.Sitefinity.News.Model.NewsItem">
# <div class="DateWrapper">
# 		Thursday, August 22, 2019
# 	</div>
# <a class="newsTitle" data-sf-field="Title" data-sf-ftype="ShortText" href="about-dbs/news-and-events/2019/08/22/5-part-time-courses-that-could-kick-start-your-career-in-2019-dbs">5 Part-Time Courses That Could Kick-start Your Career in 2019| DBS</a>
# <br/>
# <div class="sfnewsSummary sfsummary" data-sf-field="Summary" data-sf-ftype="ShortText">
# 		Whether you are looking to progress your current career or switch gears entirely – DBS offers an array of part-time evening courses designed to accommodate a working lifestyle; providing a flexible pathway to learning. We picked five DBS part-time courses to kick-start your studies in 2019.
# 	</div>
# <a class="sfnewsFullStory sffullstory" href="about-dbs/news-and-events/2019/08/22/5-part-time-courses-that-could-kick-start-your-career-in-2019-dbs" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl4_FullStory">Full story</a>
# <div class="HideListCategory" id="ctl00_ContentPlaceHolder1_C003_newsFrontendList_ctl00_ctl00_NewsList_ctrl4_HierarchicalFieldControl">
# </div>
# </li>]

# %%
item = page_soup.findAll('li',class_='sfrelatedListItem sflistitem')
readmore = page_soup.findAll('div',class_='NewsEvent_right')

# %%
data_list = []

for container in article:
    #itemlist = container.findAll('li',class_='sfnewsListItem sflistitem')
#print(itemlist)
    title = container.a.text
    div_tags = container.findAll('div')
    date = div_tags[0].text.strip()
    summary = div_tags[1].text.strip()
    location = "DBS"
    for itemlist in item:
        img = item[0].a.img['src']
        
    for readin in readmore:
        read_more = readmore[0].a['href']
   # image = itemlist[0].a['href']
 #   print(title)
 #   print(time)
 #   print(summary)
 #   print(Description)
#print(itemlist[0].div.text)
#print(itemlist[1].div.text)
    data = {}
    data["title"] = title
    data["date"] = date
    data["summary"] = summary
    data["img"] = img
    data["readmore"] = read_more
    data["location"] = location
    data_list.append(data)
    
print(data_list)
# Out:
# [{'title': '‘Why We Respond and Why We Turn Away: Human Rights Abuses in a Changing World’', 'date': 'Friday, September 13, 2019', 'summary': 'DBS recently held a psychology conference, entitled ‘Why We Respond and Why We Turn Away: Human Rights Abuses in a Changing World’. The event explored factors underlying human responses to the plight of others.', 'img': 'https://www.dbs.ie/images/default-source/default-album/img_20190906_155501-(1)fdd4042a53ff6d7ebe9cff000003f2be.tmb-.jpg?sfvrsn=5a2b69ea_1', 'readmore': 'about-dbs/news-and-events/2019/09/13/why-we-respond-and-why-we-turn-away-human-rights-abuses-in-a-changing-world', 'location': 'DBS'}, {'title': 'FinTech Breakfast Briefing with Daniel Broby', 'date': 'Friday, August 30, 2019', 'summary': "DBS FinTech Society presents A Breakfast Briefing, 'Introducing Strategic FinTech' with Daniel Broby; Director for Centre of Financial Regulation & Innovation at Strathclyde Business School.", 'img': 'https://www.dbs.ie/images/default-source/default-album/img_20190906_155501-(1)fdd4042a53ff6d7ebe9cff000003f2be.tmb-.jpg?sfvrsn=5a2b69ea_1', 'readmore': 'about-dbs/news-and-events/2019/09/13/why-we-respond-and-why-we-turn-away-human-rights-abuses-in-a-changing-world', 'location': 'DBS'}, {'title': 'Student Testimonial: John McDonnell, HDip in Science in Data Analytics', 'date': 'Thursday, August 29, 2019', 'summary': 'John McDonnell is a graduate of the Higher Diploma in Science in Data Analytics programme here at DBS. We caught up with John to ask him about his experience with the course and here is what he had to say...', 'img': 'https://www.dbs.ie/images/default-source/default-album/img_20190906_155501-(1)fdd4042a53ff6d7ebe9cff000003f2be.tmb-.jpg?sfvrsn=5a2b69ea_1', 'readmore': 'about-dbs/news-and-events/2019/09/13/why-we-respond-and-why-we-turn-away-human-rights-abuses-in-a-changing-world', 'location': 'DBS'}, {'title': ' DBS Fintech Breakfast Briefings Series', 'date': 'Monday, August 26, 2019', 'summary': "DBS FinTech Breakfast Briefings series - this week, Alan O'Sullivan from Aviva Insurance hosted the morning briefing and discussed a range of subjects, including asset allocation, modern portfolio theory, risk management and behavioural finance.", 'img': 'https://www.dbs.ie/images/default-source/default-album/img_20190906_155501-(1)fdd4042a53ff6d7ebe9cff000003f2be.tmb-.jpg?sfvrsn=5a2b69ea_1', 'readmore': 'about-dbs/news-and-events/2019/09/13/why-we-respond-and-why-we-turn-away-human-rights-abuses-in-a-changing-world', 'location': 'DBS'}, {'title': '5 Part-Time Courses That Could Kick-start Your Career in 2019| DBS', 'date': 'Thursday, August 22, 2019', 'summary': 'Whether you are looking to progress your current career or switch gears entirely – DBS offers an array of part-time evening courses designed to accommodate a working lifestyle; providing a flexible pathway to learning. We picked five DBS part-time courses to kick-start your studies in 2019.', 'img': 'https://www.dbs.ie/images/default-source/default-album/img_20190906_155501-(1)fdd4042a53ff6d7ebe9cff000003f2be.tmb-.jpg?sfvrsn=5a2b69ea_1', 'readmore': 'about-dbs/news-and-events/2019/09/13/why-we-respond-and-why-we-turn-away-human-rights-abuses-in-a-changing-world', 'location': 'DBS'}]

# %%
import pandas as pd
df = pd.DataFrame(data_list)

# %%
df
# Out:
#                          date  \
# 0  Friday, September 13, 2019
# 1     Friday, August 30, 2019
# 2   Thursday, August 29, 2019
# 3     Monday, August 26, 2019
# 4   Thursday, August 22, 2019
#
#                                                  img location  \
# 0  https://www.dbs.ie/images/default-source/defau...      DBS
# 1  https://www.dbs.ie/images/default-source/defau...      DBS
# 2  https://www.dbs.ie/images/default-source/defau...      DBS
# 3  https://www.dbs.ie/images/default-source/defau...      DBS
# 4  https://www.dbs.ie/images/default-source/defau...      DBS
#
#                                             readmore  \
# 0  about-dbs/news-and-events/2019/09/13/why-we-re...
# 1  about-dbs/news-and-events/2019/09/13/why-we-re...
# 2  about-dbs/news-and-events/2019/09/13/why-we-re...
# 3  about-dbs/news-and-events/2019/09/13/why-we-re...
# 4  about-dbs/news-and-events/2019/09/13/why-we-re...
#
#                                              summary  \
# 0  DBS recently held a psychology conference, ent...
# 1  DBS FinTech Society presents A Breakfast Brief...
# 2  John McDonnell is a graduate of the Higher Dip...
# 3  DBS FinTech Breakfast Briefings series - this ...
# 4  Whether you are looking to progress your curre...
#
#                                                title
# 0  ‘Why We Respond and Why We Turn Away: Human Ri...
# 1       FinTech Breakfast Briefing with Daniel Broby
# 2  Student Testimonial: John McDonnell, HDip in S...
# 3             DBS Fintech Breakfast Briefings Series
# 4  5 Part-Time Courses That Could Kick-start Your...
